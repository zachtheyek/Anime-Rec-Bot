# %% [markdown]
# ## Import Dependencies

# %%
import os
import numpy as np
import pandas as pd

# %% [markdown]
# ## Data Exploration

# %%
# Print filepaths under data directory
for root, dirs, files in os.walk('data'):
    for name in files:
        print(os.path.join(root, name))
# Out:
# data/anime.csv
# data/rating.csv

# %%
anime_path = 'data/anime.csv'
rating_path = 'data/rating.csv'

# %%
# Define function to check for percentage of missing values
def check_nan(df):
    print(f'Percentage of missing values in rating.csv:\n\n{round(df.isnull().sum().sort_values(ascending=False) / len(df.index), 4) * 100}')

# %% [markdown]
# The rating dataset (`rating.csv`) contains 3 columns and 7,813,737 entries:
#
# * `user_id`: non identifiable randomly generated user id.
# * `anime_id`: the anime that this user has rated.
# * `rating`: rating out of 10 this user has assigned (-1 if the user watched without assigning).

# %%
rating_df = pd.read_csv(rating_path)
rating_df
# Out:
#          user_id  anime_id  rating
# 0              1        20      -1
# 1              1        24      -1
# 2              1        79      -1
# 3              1       226      -1
# 4              1       241      -1
# ...          ...       ...     ...
# 7813732    73515     16512       7
# 7813733    73515     17187       9
# 7813734    73515     22145      10
# 7813735    73516       790       9
# 7813736    73516      8074       9
#
# [7813737 rows x 3 columns]

# %%
rating_df.shape
# Out:
# (7813737, 3)

# %%
rating_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7813737 entries, 0 to 7813736
# Data columns (total 3 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   user_id   int64
#  1   anime_id  int64
#  2   rating    int64
# dtypes: int64(3)
# memory usage: 178.8 MB

# %%
check_nan(rating_df)
# Out:
# Percentage of missing values in rating.csv:
#
# user_id     0.0
# anime_id    0.0
# rating      0.0
# dtype: float64

# %% [markdown]
# While there are no missing values in this dataset, an entry of -1 in the rating column is equivalent to a `NaN` value, so we'll foil them as such.

# %%
rating_df['rating'] = rating_df['rating'].apply(lambda x: np.nan if x == -1 else x)
rating_df
# Out:
#          user_id  anime_id  rating
# 0              1        20     NaN
# 1              1        24     NaN
# 2              1        79     NaN
# 3              1       226     NaN
# 4              1       241     NaN
# ...          ...       ...     ...
# 7813732    73515     16512     7.0
# 7813733    73515     17187     9.0
# 7813734    73515     22145    10.0
# 7813735    73516       790     9.0
# 7813736    73516      8074     9.0
#
# [7813737 rows x 3 columns]

# %% [markdown]
# The anime dataset (`anime.csv`) contains 7 columns and 12,294 entries:
#
# * `anime_id`: myanimelist.net's unique id identifying an anime.
# * `name`: full name of anime.
# * `genre`: comma separated list of genres for this anime.
# * `type`: movie, TV, OVA, etc.
# * `episodes`: how many episodes in this show. (1 if movie).
# * `rating`: average rating out of 10 for this anime.
# * `members`: number of community members that are in this anime's "group".

# %%
anime_df = pd.read_csv(anime_path)
anime_df
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 2      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 3                                       Sci-Fi, Thriller     TV       24
# 4      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                  ...    ...      ...
# 12289                                             Hentai    OVA        1
# 12290                                             Hentai    OVA        1
# 12291                                             Hentai    OVA        4
# 12292                                             Hentai    OVA        1
# 12293                                             Hentai  Movie        1
#
#        rating  members
# 0        9.37   200630
# 1        9.26   793665
# 2        9.25   114262
# 3        9.17   673572
# 4        9.16   151266
# ...       ...      ...
# 12289    4.15      211
# 12290    4.28      183
# 12291    4.88      219
# 12292    4.98      175
# 12293    5.46      142
#
# [12294 rows x 7 columns]

# %%
anime_df.shape
# Out:
# (12294, 7)

# %%
anime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12294 entries, 0 to 12293
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  12294 non-null  int64
#  1   name      12294 non-null  object
#  2   genre     12232 non-null  object
#  3   type      12269 non-null  object
#  4   episodes  12294 non-null  object
#  5   rating    12064 non-null  float64
#  6   members   12294 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 672.5+ KB

# %% [markdown]
# There are several columns with missing values, which we'll have to handle accordingly.

# %%
check_nan(anime_df)
# Out:
# Percentage of missing values in rating.csv:
#
# rating      1.87
# genre       0.50
# type        0.20
# anime_id    0.00
# name        0.00
# episodes    0.00
# members     0.00
# dtype: float64

# %% [markdown]
# Due to the small percentage of missing values, we opt to simply drop the rows with `NaN` entries.

# %%
anime_df.dropna(inplace=True)
check_nan(anime_df)
# Out:
# Percentage of missing values in rating.csv:
#
# anime_id    0.0
# name        0.0
# genre       0.0
# type        0.0
# episodes    0.0
# rating      0.0
# members     0.0
# dtype: float64

# %%
anime_df
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 2      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 3                                       Sci-Fi, Thriller     TV       24
# 4      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                  ...    ...      ...
# 12289                                             Hentai    OVA        1
# 12290                                             Hentai    OVA        1
# 12291                                             Hentai    OVA        4
# 12292                                             Hentai    OVA        1
# 12293                                             Hentai  Movie        1
#
#        rating  members
# 0        9.37   200630
# 1        9.26   793665
# 2        9.25   114262
# 3        9.17   673572
# 4        9.16   151266
# ...       ...      ...
# 12289    4.15      211
# 12290    4.28      183
# 12291    4.88      219
# 12292    4.98      175
# 12293    5.46      142
#
# [12017 rows x 7 columns]

# %% [markdown]
# ## Feature Engineering

# %%
# Create a new Dataframe combining both anime and rating via the anime_id column
rated_anime = rating_df.merge(anime_df, left_on = 'anime_id', right_on = 'anime_id', suffixes= ['_user', ''])

# Drop the irrelevant columns from the merged Dataframe
rated_anime.drop(['anime_id', 'rating_user'], axis=1, inplace=True)
rated_anime
# Out:
#          user_id                                               name  \
# 0              1                                             Naruto
# 1              3                                             Naruto
# 2              5                                             Naruto
# 3              6                                             Naruto
# 4             10                                             Naruto
# ...          ...                                                ...
# 7813606    65682  Dr. Slump: Hoyoyo! Arale no Himitsu Dai Koukai...
# 7813607    69497                                         Shiroi Zou
# 7813608    70463                                    Kakinoki Mokkii
# 7813609    72404                 Hashiri Hajimeta bakari no Kimi ni
# 7813610    72800                       Gamba: Gamba to Nakama-tachi
#
#                                                      genre     type episodes  \
# 0        Action, Comedy, Martial Arts, Shounen, Super P...       TV      220
# 1        Action, Comedy, Martial Arts, Shounen, Super P...       TV      220
# 2        Action, Comedy, Martial Arts, Shounen, Super P...       TV      220
# 3        Action, Comedy, Martial Arts, Shounen, Super P...       TV      220
# 4        Action, Comedy, Martial Arts, Shounen, Super P...       TV      220
# ...                                                    ...      ...      ...
# 7813606                            Comedy, Sci-Fi, Shounen  Special        1
# 7813607                           Action, Historical, Kids    Movie        1
# 7813608                                      Fantasy, Kids  Special        1
# 7813609                                              Music    Music        1
# 7813610                                    Adventure, Kids    Movie        1
#
#          rating  members
# 0          7.81   683297
# 1          7.81   683297
# 2          7.81   683297
# 3          7.81   683297
# 4          7.81   683297
# ...         ...      ...
# 7813606    6.17      248
# 7813607    4.71       45
# 7813608    4.33       61
# 7813609    6.76      239
# 7813610    5.55      185
#
# [7813611 rows x 7 columns]

# %%
# Count the number of unique entries in the name column
rated_anime['name'].nunique()
# Out:
# 11193
